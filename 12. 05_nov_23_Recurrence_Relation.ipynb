# %% [markdown]
# ::Recurrence Relation::

# %%
#1. Find the value of T(2) for the recurrence relation T(n) = 3T(n-1) + 12n, given that T(0)=5


'''
    Given:
    T(0)=5
    
    T(n) = 3T(n-1) + 12n ------(1)
    
    substuting eqn 1 by putting n = 1
    
    =  T(1) = 3T(1-1) + 12*1
    =  T(1) = 3 * T(0) + 12
    
    Putting the given value of T(0)
    =  T(1) = 3 * 5 + 12
    =  T(1) = 27 -----------(2)
    
    Now substuting eqn 1 by putting n = 2
    
    =  T(2) = 3T(2-1) + 12*2
    =  T(2) = 3 * T(1) + 24
    
     Putting the  value of T(2) from eqn 2
     
     T(2) = 3* 27 + 24
     T(2) = 105 ---------------(3)
     
     
     So from the eqn 3 ...We can see that the value of T(2) = 105
     
'''

# %%
#2. Given a recurrence relation, solve it using the substitution method:

#a. T(n) = T(n-1) + c
#b. T(n) = 2T(n/2) + n
#c. T(n) = 2T(n/2) + c
#d. T(n) = T(n/2) +  c


#a. T(n) = T(n-1) + c
'''
    T(n) = T(n-1) + c --------(1)
    
    substitute by n = n-1 in eqn 1
    
    = T(n-1) = T((n-1)-1) + c
    = T(n-1) = T(n-2) + c --------(2)
    
    Now put the value of T(n-1) in to eqn 1
    
    T(n) = T(n-2) + c + c
    T(n) = T(n-2) + 2c ----------(3)
    
    Substitute the eqn 1 by n = n-2
    
    T(n-2) = T((n-2)-1) + c
    T(n-2) = T(n-3) + c----------(4)
    
    Now put value of T(n-2) from eqn 4 in eqn 3
    T(n) = T(n-2) + 2c
    T(n) = T(n-3) + c + 2c
    T(n) = T(n-3) + 3c------------(5)
    
                |
            k times
                |

   From the above eqns 1, 3, 5 we can get a generalize
   T(k) = T(n-k) + k.c
   
   According to base case we can assume that
   =  n-k = 1
   =  k = n-1 -----------(6)
   
    =T(n-k) + k.c
    =T(n-(n-1)) + (n-1).c
    =T(1) + (n-1).c
    = 1 + (n-1).c--------(7)
    
    From eqn 7 we can assume that the time complexity will be O(n)
    
    So, Time complexity = O(n)
    
'''

#b. T(n) = 2T(n/2) + n

'''
    T(n)=2T(n/2)+n ---------------(1)
    
    
    Substitute n=n/2 in equation (1)

    T(n/2)=2T(n/2/2)+n/2
    T(n/2)=2T(n/4)+n/2 ---------------(2)

    Now, put the value of 

    T(n/2) from equation (2) into equation (1)
    
    T(n)=2[2T(n/4)+n/2]+n

    T(n)=4T(n/4)+2n
    
             |
            k times
             |

    Continuing this process k times:

    T(n)=2**k.T(n/2 k)+kn ---------------(3)

    Now, n/2**k=1 (Considering the base case)

    n=2**k
 
    log base 2 n=k

    Substitute the value of k in equation (3)
    
    T(n)=2**(log base2 n).T(1)+n log base2 n
    T(n)=nT(1)+nlog2n
    
    As T(1) is a constant, let's denote it as c
    T(n)=cn+nlog 2n
    
    So, Time complexity = O(n logn)
'''

#c. T(n) = 2T(n/2) + c

'''
    T(n) = 2T(n/2) + c -------(1)
    
    Substitute n = n/2
    
    T(n/2) = 2T(n/2/2) + c
    T(n/2) = 2T(n/4) + c ------(2)
    
    From eqn 2 Put the value of T(n/2) in eqn 1
    
    T(n) = 2[2T(n/4) + c] + c
    T(n) = 4T(n/4) + 2c + c
    T(n) = 4T(n/4) + 3c -------(3)
    
             |
            k times
             |

    Continuing this process k times
    
    T(n) = 2**k.T(n/(2**k)) + k.c -------(4)
    
    Now considerring base case n/(2**k) = 1
    
    n = 2**k
    log base2 of n=k
    
    Substitute the value of k in eqn 4
    
    T(n) = 2**(log base2 of n).T(n/(2**(log base2 of n))) + (log base2 of n).c
    
    T(n) = nT(1) + n.c
    
    As T(1) is a constant, let's denote it as c base2
    
    T(n) = c base2 n + n.c
    
    So the time complexity is O(n)
    
'''
#d. T(n) = T(n/2) +  c

'''

    T(n) = T(n/2) +  c ------(1)
    
    Substitute n = n/2
    
    T(n/2) = T(n/2/2) +  c
    T(n/2) = T(n/4) +  c  -------(2)
    
    put the value of T(n/2) in eqn 1
    
    T(n) = T(n/2) +  c ------(1)
    T(n) = T(n/4) +  c) +  c 
    T(n) = T(n/4) + 2c -------(3)
    
             |
            k times
             |
            
    From eqn 1 and 3 we can assume the kth term
    
    T(n) = T(n/(2**k)) + k.c ------(4)
    
    Now considerring base case n/(2**k) = 1
    
    n = 2**k
    log base2 of n=k
    
    Substitute the value of k in eqn 4
    
    T(n) = T(n/(2**(log base2 of n))) + (log base2 of n).c
    T(n) = T(1) + (log base2 of n).c
    
    As T(1) is a constant lets denote it as c base2
    
    T(n) = c base2 + (log base2 of n).c
    
    
    So the Time Complexity is O(log n)
    
    
    
'''
# Out:
# '\n\n    T(n) = T(n/2) +  c ------(1)\n    \n    Substitute n = n/2\n    \n    T(n/2) = T(n/2/2) +  c\n    T(n/2) = T(n/4) +  c  -------(2)\n    \n    put the value of T(n/2) in eqn 1\n    \n    T(n) = T(n/2) +  c ------(1)\n    T(n) = T(n/4) +  c) +  c \n    T(n) = T(n/4) + 2c -------(3)\n    \n             |\n            k times\n             |\n            \n    From eqn 1 and 3 we can assume the kth term\n    \n    T(n) = T(n/(2**k)) + k.c ------(4)\n    \n    Now considerring base case n/(2**k) = 1\n    \n    n = 2**k\n    log base2 of n=k\n    \n    Substitute the value of k in eqn 4\n    \n    T(n) = T(n/(2**(log base2 of n))) + (log base2 of n).c\n    T(n) = T(1) + (log base2 of n).c\n    \n    As T(1) is a constant lets denote it as c base2\n    \n    T(n) = c base2 + (log base2 of n).c\n    \n    \n    \n    \n    \n    \n'

# %%
#3. Given a recurrence relation, solve it %sing the recursive tree approach:
    #a. T(n) = 2T(n-1) +1
    #b. T(n) = 2T(n/2) + n
    

#a. T(n) = 2T(n-1) +1

'''
    Expanding T(n-1) in terms of T(n-2) and so on till base case
    
    T(n) = 2T(n-1) + 1
         = 2[2T(n-2) + 1] + 1
         = 2**2 T(n-2) + 2 + 1
         = 2**2 [2T(n-3) + 1] + 2 + 1
         = 2**3 T(n-3) + 2**2 + 2 + 1
         
         = 2**k T(n-k) + 2**0 + 2**1 + 2**2 +...+ 2**(k-1)
         
         When n-k = 1 
         k = n-1
         
         T(n) = 2**n-1 T(1) + 2**0 + 2**1 + 2**2 + ...+ 2**n-2
         
         express the sum 2**0 + 2**1 + 2**2 + ...+ 2**n-2 as geometric series
         
         2**0 + 2**1 + 2**2 + ...+ 2**n-2 
         
         = (2**(n-1) - 1)/2-1
         
         = 2**(n-1) - 1
         
         Substituting back into eqn
         T(n) = 2**(n-1) T(1) + (2**(n-1) - 1)
         = 2**(n-1) T(1) + 2(n-1) - 1
         
         
         So it could be exponential time complexity 
         approx O(2**n)
    
'''

#b. T(n) = 2T(n/2) + n

'''
    Expand the recurrence relation we get
   T(n) = 2T(n/2) + n
   = 2[2T(n/4) + n/2] +n
   = 2**2 T(n/4) + 2n/2 + n
   = 2**2[2T(n/8) + n/4] + 2n/2 + n
   = 2**3 T(n/8) + 3n/4 + n
   
   On both side of recurrsive approach we have addition of n
   
   expansion countinue till base case T(1) or T(2)
   
   As the division of n at each level (log n levels) and an addition of n at each step..
   we determine that time complexity T(n) is O(n log n)



'''
